# %% [markdown]
# IMPORT DATA

# %%
import pandas as pd

PATH = ".../data01.csv"
def load_mortality_data(path = PATH):
        return pd.read_csv(path)

# %% [markdown]
# DATA EXPLORATION

# %%
mortality_risk = load_mortality_data()
mortality_risk.head()
# Out:
#    group      ID  outcome  age  gendera        BMI  hypertensive  \
# 0      1  125047      0.0   72        1  37.588179             0
# 1      1  139812      0.0   75        2        NaN             0
# 2      1  109787      0.0   83        2  26.572634             0
# 3      1  130587      0.0   43        2  83.264629             0
# 4      1  138290      0.0   75        2  31.824842             1
#
#    atrialfibrillation  CHD with no MI  diabetes  ...  Blood sodium  \
# 0                   0               0         1  ...    138.750000
# 1                   0               0         0  ...    138.888889
# 2                   0               0         0  ...    140.714286
# 3                   0               0         0  ...    138.500000
# 4                   0               0         0  ...    136.666667
#
#    Blood calcium    Chloride  Anion gap  Magnesium ion     PH  Bicarbonate  \
# 0       7.463636  109.166667  13.166667       2.618182  7.230    21.166667
# 1       8.162500   98.444444  11.444444       1.887500  7.225    33.444444
# 2       8.266667  105.857143  10.000000       2.157143  7.268    30.571429
# 3       9.476923   92.071429  12.357143       1.942857  7.370    38.571429
# 4       8.733333  104.500000  15.166667       1.650000  7.250    22.000000
#
#    Lactic acid  PCO2  EF
# 0          0.5  40.0  55
# 1          0.5  78.0  55
# 2          0.5  71.5  35
# 3          0.6  75.0  55
# 4          0.6  50.0  55
#
# [5 rows x 51 columns]

# %%
mortality_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   group                     1177 non-null   int64
#  1   ID                        1177 non-null   int64
#  2   outcome                   1176 non-null   float64
#  3   age                       1177 non-null   int64
#  4   gendera                   1177 non-null   int64
#  5   BMI                       962 non-null    float64
#  6   hypertensive              1177 non-null   int64
#  7   atrialfibrillation        1177 non-null   int64
#  8   CHD with no MI            1177 non-null   int64
#  9   diabetes                  1177 non-null   int64
#  10  deficiencyanemias         1177 non-null   int64
#  11  depression                1177 non-null   int64
#  12  Hyperlipemia              1177 non-null   int64
#  13  Renal failure             1177 non-null   int64
#  14  COPD                      1177 non-null   int64
#  15  heart rate                1164 non-null   float64
#  16  Systolic blood pressure   1161 non-null   float64
#  17  Diastolic blood pressure  1161 non-null   float64
#  18  Respiratory rate          1164 non-null   float64
#  19  temperature               1158 non-null   float64
#  20  SP O2                     1164 non-null   float64
#  21  Urine output              1141 non-null   float64
#  22  hematocrit                1177 non-null   float64
#  23  RBC                       1177 non-null   float64
#  24  MCH                       1177 non-null   float64
#  25  MCHC                      1177 non-null   float64
#  26  MCV                       1177 non-null   float64
#  27  RDW                       1177 non-null   float64
#  28  Leucocyte                 1177 non-null   float64
#  29  Platelets                 1177 non-null   float64
#  30  Neutrophils               1033 non-null   float64
#  31  Basophils                 918 non-null    float64
#  32  Lymphocyte                1032 non-null   float64
#  33  PT                        1157 non-null   float64
#  34  INR                       1157 non-null   float64
#  35  NT-proBNP                 1177 non-null   float64
#  36  Creatine kinase           1012 non-null   float64
#  37  Creatinine                1177 non-null   float64
#  38  Urea nitrogen             1177 non-null   float64
#  39  glucose                   1159 non-null   float64
#  40  Blood potassium           1177 non-null   float64
#  41  Blood sodium              1177 non-null   float64
#  42  Blood calcium             1176 non-null   float64
#  43  Chloride                  1177 non-null   float64
#  44  Anion gap                 1177 non-null   float64
#  45  Magnesium ion             1177 non-null   float64
#  46  PH                        885 non-null    float64
#  47  Bicarbonate               1177 non-null   float64
#  48  Lactic acid               948 non-null    float64
#  49  PCO2                      883 non-null    float64
#  50  EF                        1177 non-null   int64
# dtypes: float64(37), int64(14)
# memory usage: 469.1 KB

# %%
mortality_risk.describe()
# Out:
#              group             ID      outcome          age      gendera  \
# count  1177.000000    1177.000000  1176.000000  1177.000000  1177.000000
# mean      1.299065  150778.120646     0.135204    74.055225     1.525064
# std       0.458043   29034.669513     0.342087    13.434061     0.499584
# min       1.000000  100213.000000     0.000000    19.000000     1.000000
# 25%       1.000000  125603.000000     0.000000    65.000000     1.000000
# 50%       1.000000  151901.000000     0.000000    77.000000     2.000000
# 75%       2.000000  176048.000000     0.000000    85.000000     2.000000
# max       2.000000  199952.000000     1.000000    99.000000     2.000000
#
#               BMI  hypertensive  atrialfibrillation  CHD with no MI  \
# count  962.000000   1177.000000         1177.000000     1177.000000
# mean    30.188278      0.717927            0.451147        0.085811
# std      9.325997      0.450200            0.497819        0.280204
# min     13.346801      0.000000            0.000000        0.000000
# 25%     24.326461      0.000000            0.000000        0.000000
# 50%     28.312474      1.000000            0.000000        0.000000
# 75%     33.633509      1.000000            1.000000        0.000000
# max    104.970366      1.000000            1.000000        1.000000
#
#           diabetes  ...  Blood sodium  Blood calcium     Chloride  \
# count  1177.000000  ...   1177.000000    1176.000000  1177.000000
# mean      0.421410  ...    138.890016       8.500894   102.283835
# std       0.493995  ...      4.151347       0.572263     5.339733
# min       0.000000  ...    114.666667       6.700000    80.266667
# 25%       0.000000  ...    136.666667       8.148864    99.000000
# 50%       0.000000  ...    139.250000       8.500000   102.500000
# 75%       1.000000  ...    141.600000       8.869063   105.571429
# max       1.000000  ...    154.736842      10.950000   122.526316
#
#          Anion gap  Magnesium ion          PH  Bicarbonate  Lactic acid  \
# count  1177.000000    1177.000000  885.000000  1177.000000   948.000000
# mean     13.925094       2.120169    7.378532    26.911766     1.853426
# std       2.652732       0.251532    0.067320     5.167512     0.983819
# min       6.636364       1.400000    7.090000    12.857143     0.500000
# 25%      12.250000       1.955556    7.334615    23.454545     1.200000
# 50%      13.666667       2.092308    7.380000    26.500000     1.600000
# 75%      15.416667       2.241667    7.430000    29.875000     2.200000
# max      25.500000       4.072727    7.580000    47.666667     8.333333
#
#              PCO2           EF
# count  883.000000  1177.000000
# mean    45.535382    48.715378
# std     12.711271    12.868436
# min     18.750000    15.000000
# 25%     37.038462    40.000000
# 50%     43.000000    55.000000
# 75%     50.585784    55.000000
# max     98.600000    75.000000
#
# [8 rows x 51 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
mortality_risk.hist(bins = 20, figsize=(30,20))
plt.show()

# %%
mortality_risk["Creatine kinase"].hist(bins = 1000, figsize=(30,20))
plt.show()

# %% [markdown]
# DATA CLEANING

# %%
#Exclude all data type that are not float64
df = mortality_risk.select_dtypes(include=['float64'])
df["EF"] = mortality_risk["EF"]
# Exclude all data that are null
df = df.dropna()
# exclude outocme
df = df.drop("outcome", axis=1)
#look at data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428 entries, 0 to 1094
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   BMI                       428 non-null    float64
#  1   heart rate                428 non-null    float64
#  2   Systolic blood pressure   428 non-null    float64
#  3   Diastolic blood pressure  428 non-null    float64
#  4   Respiratory rate          428 non-null    float64
#  5   temperature               428 non-null    float64
#  6   SP O2                     428 non-null    float64
#  7   Urine output              428 non-null    float64
#  8   hematocrit                428 non-null    float64
#  9   RBC                       428 non-null    float64
#  10  MCH                       428 non-null    float64
#  11  MCHC                      428 non-null    float64
#  12  MCV                       428 non-null    float64
#  13  RDW                       428 non-null    float64
#  14  Leucocyte                 428 non-null    float64
#  15  Platelets                 428 non-null    float64
#  16  Neutrophils               428 non-null    float64
#  17  Basophils                 428 non-null    float64
#  18  Lymphocyte                428 non-null    float64
#  19  PT                        428 non-null    float64
#  20  INR                       428 non-null    float64
#  21  NT-proBNP                 428 non-null    float64
#  22  Creatine kinase           428 non-null    float64
#  23  Creatinine                428 non-null    float64
#  24  Urea nitrogen             428 non-null    float64
#  25  glucose                   428 non-null    float64
#  26  Blood potassium           428 non-null    float64
#  27  Blood sodium              428 non-null    float64
#  28  Blood calcium             428 non-null    float64
#  29  Chloride                  428 non-null    float64
#  30  Anion gap                 428 non-null    float64
#  31  Magnesium ion             428 non-null    float64
#  32  PH                        428 non-null    float64
#  33  Bicarbonate               428 non-null    float64
#  34  Lactic acid               428 non-null    float64
#  35  PCO2                      428 non-null    float64
#  36  EF                        428 non-null    int64
# dtypes: float64(36), int64(1)
# memory usage: 127.1 KB

# %% [markdown]
# FUNCTION TO BUILD TRAINING AND TEST SETS

# %%
import numpy as np
def split_train_test(data,test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
# To keep test_set stable over many iteration, the implementation of a hash map to so that 
# every instance have a unique identifier and that if the data is update, the new data can 
# in the test_set but never the data that was used in the training set

from zlib import crc32

def test_set_check(identifier, test_ratio):
    return crc32(np.int64(identifier)) & 0Xffffffff < test_ratio * 2**32

def split_train_test_by_id(data, test_ratio, id_column):
    ids = data[id_column]
    in_test_set = ids.apply(lambda id_: test_set_check(id_,test_ratio))
    return data.loc[~in_test_set], data.loc [in_test_set]

# %%
# create training set and and test set

train_set, test_set = split_train_test(df,0.2)

# %%
print(len(train_set))
print(len(test_set))
# Out:
# 343
# 85

# %%
df = df.reset_index()
df
# Out:
#      index        BMI  heart rate  Systolic blood pressure  \
# 0        0  37.588179   68.837838               155.866667
# 1        2  26.572634   72.318182               135.333333
# 2        3  83.264629   94.500000               126.400000
# 3        5  24.262293   74.181818               118.100000
# 4        6  39.667426   69.636364               106.565217
# ..     ...        ...         ...                      ...
# 423   1088  20.347657   81.733333               109.000000
# 424   1090  26.638051   92.400000                97.130435
# 425   1091  29.836962   83.782609               109.391304
# 426   1092  32.804298   80.428571               116.300000
# 427   1094  26.255155  107.400000               101.227273
#
#      Diastolic blood pressure  Respiratory rate  temperature      SP O2  \
# 0                   68.333333         16.621622    36.714286  98.394737
# 1                   61.375000         23.640000    36.453704  95.291667
# 2                   73.200000         21.857143    36.287037  93.846154
# 3                   52.950000         20.545455    35.266667  96.818182
# 4                   47.826087         19.148148    35.603175  95.636364
# ..                        ...               ...          ...        ...
# 423                 39.310345         19.896552    36.650795  96.806452
# 424                 66.521739         25.840000    36.644444  98.040000
# 425                 73.695652         23.034483    37.380952  99.086957
# 426                 43.450000         18.560000    38.111111  97.263158
# 427                 69.818182         28.480000    36.622222  96.380952
#
#      Urine output  hematocrit  ...  Blood sodium  Blood calcium    Chloride  \
# 0          2155.0   26.272727  ...    138.750000       7.463636  109.166667
# 1          2425.0   27.700000  ...    140.714286       8.266667  105.857143
# 2          8760.0   36.637500  ...    138.500000       9.476923   92.071429
# 3          1840.0   27.333333  ...    136.250000       8.466667   96.750000
# 4          2450.0   28.937500  ...    144.133333       8.775000  106.666667
# ..            ...         ...  ...           ...            ...         ...
# 423         707.0   32.200000  ...    137.800000       7.925000  102.400000
# 424        8820.0   37.800000  ...    135.666667       8.400000  100.333333
# 425        1695.0   41.242857  ...    135.444444       8.571429   99.444444
# 426        1480.0   29.278947  ...    141.823529       8.500000  101.470588
# 427        2675.0   38.757143  ...    126.230769       8.000000   92.923077
#
#      Anion gap  Magnesium ion        PH  Bicarbonate  Lactic acid       PCO2  \
# 0    13.166667       2.618182  7.230000    21.166667        0.500  40.000000
# 1    10.000000       2.157143  7.268000    30.571429        0.500  71.500000
# 2    12.357143       1.942857  7.370000    38.571429        0.600  75.000000
# 3    13.125000       1.771429  7.310000    30.500000        0.600  65.500000
# 4    15.200000       1.875000  7.169231    26.800000        0.625  69.769231
# ..         ...            ...       ...          ...          ...        ...
# 423  16.600000       2.250000  7.273333    23.000000        3.550  48.333333
# 424  13.333333       2.050000  7.370000    26.333333        3.775  29.000000
# 425  15.888889       1.900000  7.368125    24.333333        4.150  43.000000
# 426  12.066667       2.005882  7.385806    32.933333        4.160  42.870968
# 427  16.083333       2.141667  7.430000    21.666667        4.200  21.000000
#
#      EF
# 0    55
# 1    35
# 2    55
# 3    35
# 4    55
# ..   ..
# 423  55
# 424  20
# 425  20
# 426  55
# 427  15
#
# [428 rows x 38 columns]

# %%
"""# if the data does not have an ID column, the indexation will work just fine 
df_with_id = df.reset_index()

train_set, test_set = split_train_test_by_id(df,0.2,"ID")"""

# %%
df["EF_Cat"] = pd.cut(df["EF"],
                    bins=[0, 29, 39, 52, np.inf],
                    labels=["Severe","Moderate","Mild","Normal"])

# %%
df["EF_Cat"].hist()
# Out:
# <AxesSubplot: >

# %%
# with a stratify dataset, we are making sure the test and traininig has similare proportiong
# of the same categories of patient 

from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# %%
for train_index, test_index in split.split(df, df["EF_Cat"]):
    strat_train_set = df.loc[train_index]
    strat_test_set = df.loc[test_index]

# %%
strat_test_set["EF_Cat"].value_counts() / len(strat_test_set)
# Out:
# Normal      0.546512
# Mild        0.220930
# Moderate    0.139535
# Severe      0.093023
# Name: EF_Cat, dtype: float64

# %%
# now that the data is split is stratified, you can make the data sets back to 'normal'

for set_ in (strat_train_set, strat_test_set):
    set_.drop("EF_Cat", axis = 1 , inplace = True)

# %% [markdown]
# DATA VISUALIZATION

# %%
#Make a copy of the data set to explore it visually mopre in detail
viz = strat_train_set.copy()

viz.plot(kind ="scatter", x="heart rate", y="temperature")
# Out:
# <AxesSubplot: xlabel='heart rate', ylabel='temperature'>

# %%
viz.plot(kind ="scatter", x="heart rate", y="temperature", alpha=0.1)
# Out:
# <AxesSubplot: xlabel='heart rate', ylabel='temperature'>

# %%
#lets represents the EF with a color to see if there is patern that could be indetify.
viz.plot(kind ="scatter", x="heart rate", y="temperature", alpha=0.1, 
         c="EF",cmap="jet",colorbar=True,
         )
# Out:
# <AxesSubplot: xlabel='heart rate', ylabel='temperature'>

# %% [markdown]
# Looking for Correlation

# %%
corr_matrix = viz.corr()
#how much heart rate and temperature are correlated to EF
corr_matrix["EF"].sort_values(ascending=False)
# Out:
# EF                          1.000000
# Systolic blood pressure     0.245146
# Blood sodium                0.160560
# PCO2                        0.139248
# Bicarbonate                 0.101188
# BMI                         0.096157
# Chloride                    0.093234
# temperature                 0.087958
# MCH                         0.082250
# MCHC                        0.065418
# MCV                         0.063629
# Platelets                   0.034780
# Urine output                0.032480
# Blood calcium               0.029785
# Neutrophils                 0.021063
# glucose                     0.000124
# INR                        -0.007788
# Magnesium ion              -0.008600
# PT                         -0.018369
# PH                         -0.021040
# index                      -0.027579
# Leucocyte                  -0.039071
# Lymphocyte                 -0.040810
# RDW                        -0.040941
# SP O2                      -0.049060
# Creatine kinase            -0.050256
# heart rate                 -0.055840
# Basophils                  -0.059270
# Blood potassium            -0.070958
# hematocrit                 -0.078508
# Creatinine                 -0.079578
# Diastolic blood pressure   -0.089316
# Urea nitrogen              -0.089773
# Respiratory rate           -0.092389
# RBC                        -0.104253
# Anion gap                  -0.177664
# NT-proBNP                  -0.179575
# Lactic acid                -0.208512
# Name: EF, dtype: float64

# %%
# look at the first 5 elements to see normality of distribution
from pandas.plotting import scatter_matrix
attributes = [] # attibutes list will be use latter in this code
for col in viz.columns:
    attributes.insert(-1,col)
scatter_matrix(viz[["Systolic blood pressure","Blood sodium","PCO2","Bicarbonate"]])
# Out:
# array([[<AxesSubplot: xlabel='Systolic blood pressure', ylabel='Systolic blood pressure'>,
#         <AxesSubplot: xlabel='Blood sodium', ylabel='Systolic blood pressure'>,
#         <AxesSubplot: xlabel='PCO2', ylabel='Systolic blood pressure'>,
#         <AxesSubplot: xlabel='Bicarbonate', ylabel='Systolic blood pressure'>],
#        [<AxesSubplot: xlabel='Systolic blood pressure', ylabel='Blood sodium'>,
#         <AxesSubplot: xlabel='Blood sodium', ylabel='Blood sodium'>,
#         <AxesSubplot: xlabel='PCO2', ylabel='Blood sodium'>,
#         <AxesSubplot: xlabel='Bicarbonate', ylabel='Blood sodium'>],
#        [<AxesSubplot: xlabel='Systolic blood pressure', ylabel='PCO2'>,
#         <AxesSubplot: xlabel='Blood sodium', ylabel='PCO2'>,
#         <AxesSubplot: xlabel='PCO2', ylabel='PCO2'>,
#         <AxesSubplot: xlabel='Bicarbonate', ylabel='PCO2'>],
#        [<AxesSubplot: xlabel='Systolic blood pressure', ylabel='Bicarbonate'>,
#         <AxesSubplot: xlabel='Blood sodium', ylabel='Bicarbonate'>,
#         <AxesSubplot: xlabel='PCO2', ylabel='Bicarbonate'>,
#         <AxesSubplot: xlabel='Bicarbonate', ylabel='Bicarbonate'>]],
#       dtype=object)

# %% [markdown]
# Building A Machine learning algorithms to predict EF

# %%
#variables of interests
var = strat_train_set.drop("EF",axis=1)

#predictors
pred = strat_train_set["EF"].copy()

# %% [markdown]
# Transformation Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="median")),
        ('std_scaler', StandardScaler())
    ])

var_prepared = num_pipeline.fit_transform(var)

# %% [markdown]
# Training an Evaluationg on the training set

# %%
## LINEAR REGRESSION ##
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(var_prepared,pred)

## TEST WITH THE TRAIN SET ##
x_test_one = var.iloc[:5]
y_test_one = pred.iloc[:5]

linRegModel_test_1 = num_pipeline.transform(x_test_one)
print("Predictions: ", lin_reg.predict(linRegModel_test_1))
print("Real EF: ", list(y_test_one))
# Out:
# Predictions:  [50.51620935 50.87683111 55.7745405  61.50032722 49.32044399]
# Real EF:  [50, 55, 75, 55, 55]

# %%
## TEST ON ON THE WHOLE DATA SET AND MEASURE THE ERROR WITH RMSE ##
from sklearn.metrics import mean_squared_error

EF_prediction = lin_reg.predict(var_prepared)
lin_mse = mean_squared_error(pred, EF_prediction)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 11.286948186562027

# %%
## A difference of 11% is not good enough ##
## A more powerfull model will be tested ##

## DECISION TREE REGRESSOR ##
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(var_prepared,pred)

## Now that the model is train, time to predict ##
EF_prediction = tree_reg.predict(var_prepared)
tree_mse = mean_squared_error(pred, EF_prediction)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %% [markdown]
# CROSS VALIDATION with k-fold cross-validation and DECISION TREE REGRESSOR

# %%
## k-fold cross-validation ##
from sklearn.model_selection import cross_val_score

tree_scores = cross_val_score(tree_reg, var_prepared, pred,scoring="neg_mean_squared_error",cv=10)
tree_rmse_scores = np.sqrt(-tree_scores)

## Let's look at results ##
def display_scores(scores):
    print("Scores: ", scores)
    print("Mean: ", scores.mean())
    print("Standart deviation", round(scores.std(),2))
display_scores(tree_rmse_scores)
# Out:
# Scores:  [16.21286967 16.21286967 16.62740474 18.4709629  18.00735144 15.24312767
#  16.7156144  13.36699183 15.0977209  18.70828693]
# Mean:  16.46632001498982
# Standart deviation 1.57

# %% [markdown]
# COMPARE PERFORMANCES OF DECISION TREE AND LINEAR REGRESSION

# %%
lin_scores = cross_val_score(lin_reg, var_prepared,pred,scoring="neg_mean_squared_error",cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)

display_scores(lin_rmse_scores)
# Out:
# Scores:  [15.49812174 11.5941208  11.03275273 15.29757785 11.22571885 12.59645138
#  11.54451157 13.57474295 12.43232116 13.06060395]
# Mean:  12.785692297535988
# Standart deviation 1.52

# %% [markdown]
# CROSS VALIDATION with k-fold cross-validation and RANDOM FOREST REGRESSOR

# %%
## RANDOM FOREST REGRESSOR ##
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor()
forest_reg.fit(var_prepared,pred)

## Now that the model is train, time to predict ##
EF_prediction = forest_reg.predict(var_prepared)
forest_mse = mean_squared_error(pred, EF_prediction)
forest_rmse = np.sqrt(forest_mse)
forest_rmse # -> 4.645717389002427

## k-fold cross-validation ##


forest_scores = cross_val_score(forest_reg, var_prepared, pred,scoring="neg_mean_squared_error",cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores:  [13.32922139 11.87893995 10.06095394 14.04542525 10.39934599 12.51749952
#  12.15042967 13.61174072 11.6652261  13.57389092]
# Mean:  12.323267344344838
# Standart deviation 1.29

# %%
len(attributes)
# Out:
# 38

# %% [markdown]
# FINE-TUNE : Grid search

# %%
from sklearn.model_selection import GridSearchCV
##note -> n_estimatorsint : The number of trees in the forest || max_features : The number of features to consider when looking for the best split:

param_dist = [
    {'n_estimators':[1,10,100,500],'max_features': [1,2,3,5,8,13,21,34,38],'bootstrap':[True]}
]

grid_search = GridSearchCV(forest_reg,param_dist,cv=5,scoring='neg_mean_squared_error',return_train_score=True)
grid_search.fit(var_prepared,pred)

## Let's see the resutls
cvres = grid_search.cv_results_
for mean_scores, prarams, in zip(cvres["mean_test_score"],cvres["params"]):
    print(np.sqrt(-mean_scores),prarams)
# Out:
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 1041, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 859, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 777, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in __call__
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\joblib\parallel.py", line 262, in <listcomp>
#     return [func(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\fixes.py", line 222, in __call__
#     return self.function(*args, **kwargs)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\ensemble\_forest.py", line 169, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 1247, in fit
#     super().fit(
#   File "c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\tree\_classes.py", line 288, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [-304.71973572 -164.90218457 -154.59757161 -154.70885755 -296.98209719
#  -173.75912191 -158.209013   -152.60194809 -334.45439045 -167.16463129
#  -154.89947538 -153.11543914 -330.03623188 -165.75708653 -155.13859516
#  -153.28044132 -336.1913896  -170.91203112 -155.18956298 -153.0002759
#  -285.80242967 -163.73098892 -157.69846494 -152.97130607 -296.55690537
#  -168.26409847 -155.36653559 -151.60140358 -353.99722933 -166.14268968
#  -152.45378186 -153.93458014           nan           nan           nan
#            nan]
#   warnings.warn(
# c:\Users\Chuck\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the train scores are non-finite: [-100.48020106  -30.53444961  -21.98635049  -21.16649389 -103.30017914
#   -30.32173806  -21.82442141  -20.86900555 -120.14839175  -30.11661854
#   -21.33502428  -20.96802701 -115.58621427  -30.77545186  -21.66839121
#   -21.00272978 -114.10049197  -29.40165437  -20.96963313  -20.80302451
#  -116.24929815  -28.81000575  -21.46258053  -20.70617748 -123.35619368
#   -27.21334389  -21.88628406  -20.94089681 -119.84806556  -29.74594463
#   -21.73043868  -20.96849461           nan           nan           nan
#            nan]
#   warnings.warn(
# 17.456223409442693 {'bootstrap': True, 'max_features': 1, 'n_estimators': 1}
# 12.841424553743249 {'bootstrap': True, 'max_features': 1, 'n_estimators': 10}
# 12.433727180988539 {'bootstrap': True, 'max_features': 1, 'n_estimators': 100}
# 12.438201539974322 {'bootstrap': True, 'max_features': 1, 'n_estimators': 500}
# 17.233168518490753 {'bootstrap': True, 'max_features': 2, 'n_estimators': 1}
# 13.181772335677529 {'bootstrap': True, 'max_features': 2, 'n_estimators': 10}
# 12.578116432950226 {'bootstrap': True, 'max_features': 2, 'n_estimators': 100}
# 12.353216103119324 {'bootstrap': True, 'max_features': 2, 'n_estimators': 500}
# 18.288094226896167 {'bootstrap': True, 'max_features': 3, 'n_estimators': 1}
# 12.929216189982187 {'bootstrap': True, 'max_features': 3, 'n_estimators': 10}
# 12.445861777459674 {'bootstrap': True, 'max_features': 3, 'n_estimators': 100}
# 12.373982347609841 {'bootstrap': True, 'max_features': 3, 'n_estimators': 500}
# 18.166899347000797 {'bootstrap': True, 'max_features': 5, 'n_estimators': 1}
# 12.874668404672187 {'bootstrap': True, 'max_features': 5, 'n_estimators': 10}
# 12.45546446994161 {'bootstrap': True, 'max_features': 5, 'n_estimators': 100}
# 12.380647855479863 {'bootstrap': True, 'max_features': 5, 'n_estimators': 500}
# 18.335522615931023 {'bootstrap': True, 'max_features': 8, 'n_estimators': 1}
# 13.073332823606785 {'bootstrap': True, 'max_features': 8, 'n_estimators': 10}
# 12.45751030421166 {'bootstrap': True, 'max_features': 8, 'n_estimators': 100}
# 12.369328029592626 {'bootstrap': True, 'max_features': 8, 'n_estimators': 500}
# 16.9056922268069 {'bootstrap': True, 'max_features': 13, 'n_estimators': 1}
# 12.795741046039735 {'bootstrap': True, 'max_features': 13, 'n_estimators': 10}
# 12.55780494116404 {'bootstrap': True, 'max_features': 13, 'n_estimators': 100}
# 12.3681569389155 {'bootstrap': True, 'max_features': 13, 'n_estimators': 500}
# 17.220827662189876 {'bootstrap': True, 'max_features': 21, 'n_estimators': 1}
# 12.971665215594841 {'bootstrap': True, 'max_features': 21, 'n_estimators': 10}
# 12.464611329379583 {'bootstrap': True, 'max_features': 21, 'n_estimators': 100}
# 12.312652175093115 {'bootstrap': True, 'max_features': 21, 'n_estimators': 500}
# 18.814814092265518 {'bootstrap': True, 'max_features': 34, 'n_estimators': 1}
# 12.88963497095901 {'bootstrap': True, 'max_features': 34, 'n_estimators': 10}
# 12.347217575743334 {'bootstrap': True, 'max_features': 34, 'n_estimators': 100}
# 12.407037524582666 {'bootstrap': True, 'max_features': 34, 'n_estimators': 500}
# nan {'bootstrap': True, 'max_features': 38, 'n_estimators': 1}
# nan {'bootstrap': True, 'max_features': 38, 'n_estimators': 10}
# nan {'bootstrap': True, 'max_features': 38, 'n_estimators': 100}
# nan {'bootstrap': True, 'max_features': 38, 'n_estimators': 500}

# %% [markdown]
# EVALUATE THE IMPORTANCE OF EACH ATTRIBUTE

# %%
features_importance = grid_search.best_estimator_.feature_importances_
sorted(zip(features_importance,attributes),reverse=True)
# Out:
# [(0.07727693125535105, 'Diastolic blood pressure'),
#  (0.06590250305611947, 'Creatine kinase'),
#  (0.05417637512307918, 'Creatinine'),
#  (0.049426392992705764, 'PCO2'),
#  (0.04621852108805262, 'Respiratory rate'),
#  (0.045342606878261346, 'Blood calcium'),
#  (0.031136638245737747, 'SP O2'),
#  (0.02921554440342804, 'Urine output'),
#  (0.028646454490471835, 'Anion gap'),
#  (0.028375273319744237, 'MCV'),
#  (0.028212075997859822, 'temperature'),
#  (0.025657064673261686, 'Leucocyte'),
#  (0.02441687771653813, 'BMI'),
#  (0.024189772862658665, 'EF'),
#  (0.024186024960336554, 'Chloride'),
#  (0.022842991875319074, 'Magnesium ion'),
#  (0.022436705426155935, 'Blood potassium'),
#  (0.02198613765712772, 'MCHC'),
#  (0.021619845932331842, 'MCH'),
#  (0.02146786912950386, 'Platelets'),
#  (0.021442023261202717, 'NT-proBNP'),
#  (0.020794321733714476, 'PT'),
#  (0.01991466013501449, 'PH'),
#  (0.019466792182601538, 'heart rate'),
#  (0.019349568908183706, 'INR'),
#  (0.019348178374145146, 'Urea nitrogen'),
#  (0.019181413236106174, 'glucose'),
#  (0.018888779646018258, 'RDW'),
#  (0.018797650323460726, 'Blood sodium'),
#  (0.018597252761940835, 'hematocrit'),
#  (0.01760527958453878, 'Neutrophils'),
#  (0.017310526555462988, 'RBC'),
#  (0.01705161484877738, 'Basophils'),
#  (0.016975652383382733, 'Bicarbonate'),
#  (0.016246537068342705, 'Systolic blood pressure'),
#  (0.01391676130189902, 'Lactic acid'),
#  (0.01238038061116369, 'Lymphocyte')]

# %% [markdown]
# EVALUATE ON TEST SET

# %%
final_model = grid_search.best_estimator_
final_model # ->12.31%
# Out:
# RandomForestRegressor(max_features=21, n_estimators=500)

# %%
#Data with the Highest corrolation with EF - OPTIONAL
#variables of interests
var_test = strat_test_set.drop("EF",axis=1)

#predictors
pred_test = strat_test_set["EF"].copy()

var_test_prepared = num_pipeline.fit_transform(var_test)

final_prediction = final_model.predict(var_test_prepared)
final_mse = mean_squared_error(pred_test,final_prediction)
final_rmse = np.sqrt(final_mse)# -> 12.504368614895538 
final_rmse
# Out:
# 12.380303232939607

# %%
## CONFIDENCE INTERVALS ##
from scipy import stats
confidence = 0.95
squared_errors = (final_prediction - pred_test)**2
np.sqrt(stats.t.interval(confidence, len(squared_errors)-1,
                        loc=squared_errors.mean(),
                         scale=stats.sem(squared_errors)))
#->[11.07250765, 13.78832996]
# Out:
# array([10.39920278, 14.08546761])
